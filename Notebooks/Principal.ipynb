# %%
# Script Principal - Projeto de Detecção de Fraudes em Entregas do Walmart
# Autor: [Seu Nome]
# Data: Abril/2025

# Importando os módulos do projeto
import sys
import os
import time
import warnings
warnings.filterwarnings('ignore')

print("="*80)
print("PROJETO: DETECÇÃO DE FRAUDES EM ENTREGAS DO WALMART")
print("="*80)
print("\nIniciando pipeline de análise...\n")

# Etapa 1: Preparação e Limpeza dos Dados
print("\n" + "="*50)
print("ETAPA 1: PREPARAÇÃO E LIMPEZA DOS DADOS")
print("="*50 + "\n")

print("Importando módulo de preparação de dados...")
try:
    from data_preparation import load_and_clean_data, create_sqlite_database, main as prep_main
    print("Executando preparação de dados...")
    prep_main()
except Exception as e:
    print(f"Erro na etapa de preparação de dados: {e}")
    sys.exit(1)

# Etapa 2: Análise Exploratória de Dados
print("\n" + "="*50)
print("ETAPA 2: ANÁLISE EXPLORATÓRIA DE DADOS")
print("="*50 + "\n")

print("Importando módulo de análise exploratória...")
try:
    from data_analysis import load_data, exploratory_data_analysis, detect_fraud_patterns, main as analysis_main
    print("Executando análise exploratória...")
    analysis_main()
except Exception as e:
    print(f"Erro na etapa de análise exploratória: {e}")
    sys.exit(1)

# Etapa 3: Modelagem para Detecção de Fraudes
print("\n" + "="*50)
print("ETAPA 3: MODELAGEM PARA DETECÇÃO DE FRAUDES")
print("="*50 + "\n")

print("Importando módulo de modelagem...")
try:
    from fraud_detection_models import load_and_prepare_data, detect_anomalies_with_isolation_forest, cluster_drivers_with_kmeans, create_predictive_model, main as model_main
    print("Executando modelagem para detecção de fraudes...")
    model_main()
except Exception as e:
    print(f"Erro na etapa de modelagem: {e}")
    sys.exit(1)

# Etapa 4: Geração de Recomendações e Dashboard
print("\n" + "="*50)
print("ETAPA 4: RECOMENDAÇÕES E DASHBOARD")
print("="*50 + "\n")

print("Importando módulo de recomendações e dashboard...")
try:
    from recommendations_dashboard import load_data_and_models, generate_recommendations, create_dashboard_visualizations, generate_final_report, main as recommendations_main
    print("Gerando recomendações e criando dashboard...")
    recommendations_main()
except Exception as e:
    print(f"Erro na etapa de recomendações e dashboard: {e}")
    sys.exit(1)

print("\n" + "="*80)
print("PROJETO CONCLUÍDO COM SUCESSO!")
print("="*80)

print("\nResultados disponíveis nos seguintes arquivos:")
print("1. relatorio_fraudes_walmart.md - Relatório completo")
print("2. walmart_fraud_dashboard.html - Dashboard interativo")
print("3. Diversos arquivos HTML com visualizações individuais")
print("4. Modelos salvos (isolation_forest_model.joblib, rf_classifier_model.joblib, etc.)")

print("\nPara visualizar o dashboard, abra o arquivo 'walmart_fraud_dashboard.html' em um navegador web.")
print("Para ler o relatório completo, abra o arquivo 'relatorio_fraudes_walmart.md' em um editor de texto ou visualizador markdown.")
# Out:
# ...
# PROJETO: DETECÇÃO DE FRAUDES EM ENTREGAS DO WALMART
# ...
#
# Iniciando pipeline de análise...
#
#
# ...
# ETAPA 1: PREPARAÇÃO E LIMPEZA DOS DADOS
# ...
#
# Importando módulo de preparação de dados...
# Erro na etapa de preparação de dados: No module named 'data_preparation'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
